# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
ls
# Out:
# AlphaOri_AAVSO_ATEL.csv  README.md
# LICENSE                  Untitled.ipynb

# %%
data = pd.read_csv('AlphaOri_AAVSO_ATEL.csv',index_col=0)

# %%
plt.scatter(data['time'],data['Vmag'])
plt.gca().invert_yaxis()
